# %%
s1="python"
s2="datascience"
s3="""l1
l2"""
print(s1,s2,s3)
# Out:
# python datascience l1
# l2

# %%
print("Arpit"+" Prabhakar")
print("ha"*3)
print("oops" in "loops and dictionary")     
print("ab" < "ad")
# Out:
# Arpit Prabhakar
# hahaha
# True
# True

# %%
l=["arpit","prabhakar"]
"arpit" in l
# Out:
# True

# %%
s="prabhakar"
print(s[0:])
print(s[-1])
print(s[len(s):])
# Out:
# prabhakar
# r

# %%
st="string"
print(st[:])
print(st[:3])
print(st[:2:-1])
# Out:
# string
# str
# gni

# %% [markdown]
# > SPLIT()

# %%
print("we're the champions!!!".split())
print("@#!$-$!@#%#!@$!".split("@"))
# Out:
# ["we're", 'the', 'champions!!!']
# ['', '#!$-$!', '#%#!', '$!']

# %% [markdown]
# >lists

# %%
l=[16 , 14, 12]
MID=[12,"apm",.31, False]
mt=[]
print(l,MID,mt)
# Out:
# [16, 14, 12] [12, 'apm', 0.31, False] []

# %%
l=[-1,-2,0,1,1.0000000000000001,1.1,1.2,1.3,1.5,1.7,1.9,2.1,2,3,4,5]
l.append(True)
print(l)
l.sort()
print(l)
# Out:
# [-1, -2, 0, 1, 1.0, 1.1, 1.2, 1.3, 1.5, 1.7, 1.9, 2.1, 2, 3, 4, 5, True]
# [-2, -1, 0, 1, 1.0, True, 1.1, 1.2, 1.3, 1.5, 1.7, 1.9, 2, 2.1, 3, 4, 5]

# %%
#there are two arbitary length list of diff class in how many ways two students can sit together 
class_a=["a","b","c","d"]
class_b=['d',"e","f","g"]
for student_a in (class_a):
    for student_b in (class_b):
        if student_a == student_b:
            continue
        else:
            print(student_a,student_b)
# Out:
# a d
# a e
# a f
# a g
# b d
# b e
# b f
# b g
# c d
# c e
# c f
# c g
# d e
# d f
# d g

# %%
r1 = int(input("Enter rows of Matrix A: "))
c1 = int(input("Enter columns of Matrix A: "))

r2 = int(input("Enter rows of Matrix B: "))
c2 = int(input("Enter columns of Matrix B: "))

if c1 != r2:
    print("Matrix multiplication not possible!")
else:
    A = []
    B = []
    result = []

    print("Enter elements of Matrix A:")
    for i in range(r1):
        row = []
        for j in range(c1):
            element = int(input())
            row.append(element)
        A.append(row)

    print("Enter elements of Matrix B:")
    for i in range(r2):
        row = []
        for j in range(c2):
            element = int(input())
            row.append(element)
        B.append(row)

    for i in range(r1):
        row = []
        for j in range(c2):
            row.append(0)
        result.append(row)

    for i in range(r1):
        for j in range(c2):
            for k in range(c1):
                result[i][j] += A[i][k] * B[k][j]

    print("Result Matrix:")
    for i in range(r1):
        for j in range(c2):
            print(result[i][j], end=" ")
        print()
# Out:
# Enter elements of Matrix A:
# Enter elements of Matrix B:
# Result Matrix:
# 122 36 140
# 228 60 248
# 607 261 544

# %%
# Input matrix sizes
r1 = int(input("Enter rows of Matrix A: "))
c1 = int(input("Enter columns of Matrix A: "))
    # Create empty matrices
    A = []
    result = []
