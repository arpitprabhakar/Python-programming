# %% [markdown]
# # **Experiment 1: Python Installation and starting with python**

# %% [markdown]
# 1) <h3 style="color: plum;"><b>Install Python and understand difference between scripting and interactive modes in IDLE.</b></h3>
#
# Python is a high-level, interpreted, and object-oriented programming language.
#
# It can be used in two different modes in IDLE (Integrated Development and Learning Environment):
#
# 1) Interactive Mode
#
# 2) Scripting Mode
#
# Installation:
#
#     To install Python on the system and understand the difference between Scripting Mode and Interactive Mode in Python IDLE.
#
#     Software Required
#
#     Operating System: Windows 10 / Linux / macOS
#
#     Python Version: Python 3.9 or newer versions
#
# <hr>
#
#     procedure:
#
# Step 1: Installing Python
#
# ~ Go to the official Python website: https://www.python.org
#
# ~ Download the latest Python 3 version.
#
# ~ Run the installer.
#
# ~ Select “Add Python to PATH”.
#
# ~ Click Install Now.
#
# ~ After installation, verify by typing python --version in Command Prompt.
#
# Step 2: Working with Python in VS Code and Jupyter Notebook
#
# ~ Download and install Visual Studio Code from the official website.
#
# ~ Open VS Code.
#
# ~ Go to Extensions (Ctrl + Shift + X).
#
# ~ Install the Python extension by Microsoft.
#
# ~ press ctrl+p and create an environment for python (venv)
#
# ~ Install Jupyter Notebook using the command:
#
# >pip install notebook
#
# ~ Open Command Prompt / Terminal.
#
# >Type: jupyter notebook
#
# ~ Click New → Python 3 Notebook.

# %% [markdown]
# 2) <h3 style="color: plum;"><b>Write Python programs to print strings in the given manner:
# **a)   Hello Everyone !!!**
# **b)   Hello**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**World**
# **c)   Hello**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**World**
# **d) ‘ Rohit’ s date of birth is 12\05\1999’**</b></h3>

# %%
print("Hello Everyone !!!")
# Out:
# Hello Everyone !!!

# %%
print("Hello \nWorld")
# Out:
# Hello
# World

# %%
print("Hello\n\tWorld")
# Out:
# Hello
# 	World

# %%
print("'Rohit's date of birth is 12\\05\\1999'")
# Out:
# 'Rohit's date of birth is 12\05\1999'

# %% [markdown]
# 3) <h3 style="color: plum;"><b>Declare a string variable called x and assign it the value “Hello”. Print out the value of x</b></h3>

# %%
x="Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# 4) <h3 style="color: plum;"><b>Take different data types and print values using print function.</b></h3>

# %%
a=20.08
b="Arpit"
c=20
d=True
print(a)
print(b)
print(c)
print(d)
# Out:
# 20.08
# Arpit
# 20
# True

# %% [markdown]
# 5) <h3 style="color: plum;"><b>Take two variables, a and b. Assign your first name and last name. Print your Name after adding your First name and Last name together</b></h3>

# %%
f_name="Arpit"
l_name="Prabhakar"
print(f_name+" "+l_name)
# Out:
# Arpit Prabhakar

# %% [markdown]
# 6) <h3 style="color: plum;"><b>Declare three variables, consisting of your first name, your last name and Nickname. Write a program that prints out your first name, then your nickname in parenthesis and then your last name.**
# **Example output: George (woody) Washington.**</b></h3>

# %%
f_name="George"
n_name="R.R."
l_name="Martin"
print(f_name+" ("+n_name+") "+l_name)
# Out:
# George (R.R.) Martin

# %% [markdown]
# 7) <h3 style="color: plum;"><b>Declare and assign values to suitable variables and print in the following way:
# **NAME: NIKUNJ BANSAL**
# **SAP ID: 500069944**
# **DATE OF BIRTH: 13 Oct 1999**
# **ADDRESS: UPES**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Bidholi Campus**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Pincode: 248007**
# **Programme:AI & ML**
# **Semester: 2**</b></h3>

# %%
name="NIKUNJ BANSAL"
id=590024814
dob="13 Oct 1999"
add="UPES\n\tBidholi Campus\n\tPincode: 248007"
prog="AI & ML"
sem=2
print("NAME:", name)
print("SAP_ID:", id)
print("DATE OF BIRTH:", dob)
print("ADDRESS:", add)
print("PROGRAMME:", prog)
print("SEMESTER:", sem)
# Out:
# NAME: NIKUNJ BANSAL
# SAP_ID: 590024814
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
# 	Bidholi Campus
# 	Pincode: 248007
# PROGRAMME: AI & ML
# SEMESTER: 2
